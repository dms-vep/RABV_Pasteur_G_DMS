# %%
import pandas as pd

# %%
#pull in current barcode runs so that I do not need to maintain ALL my prior selections. 

barcode_runs_current = pd.read_csv('barcode_runs_current_2040406_2.csv')

# %%
barcode_runs_current
# Out:
#     Unnamed: 0                           sample library      date  \
# 0            0  A-240129-rescue_1-no_antibody-1       A  20240129
# 1            1  A-240129-rescue_1-no_antibody-2       A  20240129
# 2            2         A-240129-rescue_1-VSVG-1       A  20240129
# 3            3  A-240222-rescue_2-no_antibody-1       A  20240222
# 4            4  A-240222-rescue_2-no_antibody-2       A  20240222
# 5            5  A-240222-rescue_2-no_antibody-3       A  20240222
# 6            6         A-240222-rescue_2-VSVG-1       A  20240222
# 7            7   A-240319-rescue_2-RVA122-150-1       A  20240319
# 8            8   A-240319-rescue_2-RVA122-300-1       A  20240319
# 9            9   A-240319-rescue_2-RVA122-600-1       A  20240319
# 10          10  A-240319-rescue_2-RVA122-1500-1       A  20240319
# 11          11  A-240319-rescue_2-RVA122-3000-1       A  20240319
# 12          12  A-240319-rescue_2-no_antibody-1       A  20240319
# 13          13  A-240319-rescue_2-no_antibody-2       A  20240319
# 14          14  A-240319-rescue_2-no_antibody-3       A  20240319
# 15          15    A-240319-rescue_2-RVC20-300-1       A  20240319
# 16          16    A-240319-rescue_2-RVC20-600-1       A  20240319
# 17          17   A-240319-rescue_2-RVC20-1200-1       A  20240319
# 18          18   A-240319-rescue_2-RVC20-3000-1       A  20240319
# 19          19   A-240319-rescue_2-RVC20-6000-1       A  20240319
# 20          20     A-240319-rescue_2-17C7-800-1       A  20240319
# 21          21    A-240319-rescue_2-17C7-2000-1       A  20240319
# 22          22    A-240319-rescue_2-17C7-4000-1       A  20240319
# 23          23   A-240319-rescue_2-17C7-10000-1       A  20240319
# 24          24   A-240319-rescue_2-17C7-25000-1       A  20240319
# 25           0  A-240331-rescue_4-no_antibody-1       A  20240331
# 26           1  A-240331-rescue_4-no_antibody-2       A  20240331
# 27           2  A-240331-rescue_4-no_antibody-3       A  20240331
# 28           3     A-240331-rescue_4-RVC58-50-1       A  20240331
# 29           4    A-240331-rescue_4-RVC58-250-1       A  20240331
# 30           5    A-240331-rescue_4-RVC58-500-1       A  20240331
# 31           6   A-240331-rescue_4-RVC58-1000-1       A  20240331
# 32           7   A-240331-rescue_4-RVC58-2500-1       A  20240331
# 33           8   A-240331-rescue_4-RVC58-5000-1       A  20240331
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 4   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 5   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 6   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 7   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 8   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 9   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 10  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 11  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 12  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 13  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 14  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 15  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 16  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 17  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 18  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 19  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 20  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 21  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 22  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 23  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 24  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 25  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 26  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 27  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 28  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 29  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 30  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 31  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 32  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 33  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN

# %%
#need to format sample names
lib = 'A';
date_selection = '240331'
rescue_num='4'; 

#notes rescue 1 was done on 13-Jan-2024; Rescue 2 was done 18-Jan-2024. Rescue 3 was done 09-Mar-2024

#either add string name of antibody (eg. 'RVA122'), say 'no_antibody', or 'VSVG' for VSV-G selections
#Then add '-#' where # is the replicate number. Eg replicate 1 is '-1' and so on.

conditions = ['CR4098-400-1',
              'CR4098-2000-1',
              'CR4098-4000-1',
              'CR4098-8000-1',
              'CR4098-20000-1',
              'CR4098-40000-1'];


#make sample names
sample_names = []

for i in conditions:
    sample = lib+'-'+date_selection+'-'+'rescue_'+rescue_num+'-'+i;
    print(sample)
    sample_names.append(sample)

print(sample_names)
# Out:
# A-240331-rescue_4-CR4098-400-1
# A-240331-rescue_4-CR4098-2000-1
# A-240331-rescue_4-CR4098-4000-1
# A-240331-rescue_4-CR4098-8000-1
# A-240331-rescue_4-CR4098-20000-1
# A-240331-rescue_4-CR4098-40000-1
# ['A-240331-rescue_4-CR4098-400-1', 'A-240331-rescue_4-CR4098-2000-1', 'A-240331-rescue_4-CR4098-4000-1', 'A-240331-rescue_4-CR4098-8000-1', 'A-240331-rescue_4-CR4098-20000-1', 'A-240331-rescue_4-CR4098-40000-1']

# %%
#copy-paste directories -- match order for names

directories=['/shared/ngs/illumina/aaditham/240405_VH01189_267_AAFK7WYM5/Unaligned/Project_aaditham/LibA_CR4098_400_S13_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240405_VH01189_267_AAFK7WYM5/Unaligned/Project_aaditham/LibA_CR4098_2000_S14_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240405_VH01189_267_AAFK7WYM5/Unaligned/Project_aaditham/LibA_CR4098_4000_S15_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240405_VH01189_267_AAFK7WYM5/Unaligned/Project_aaditham/LibA_CR4098_8000_S16_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240405_VH01189_267_AAFK7WYM5/Unaligned/Project_aaditham/LibA_CR4098_20000_S17_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240405_VH01189_267_AAFK7WYM5/Unaligned/Project_aaditham/LibA_CR4098_40000_S18_R1_001.fastq.gz'];

# %%
library='A';
date_value = 20240331;

libraries = [];
date = [];

for i in range(0, len(directories)):
    libraries.append(library);
    date.append(date_value);

# %%
print(libraries)
print(date)
# Out:
# ['A', 'A', 'A', 'A', 'A', 'A']
# [20240331, 20240331, 20240331, 20240331, 20240331, 20240331]

# %%
#update barcode_runs_new
barcode_runs_new = pd.DataFrame()

barcode_runs_new['sample']=sample_names;
barcode_runs_new['library']=libraries;
barcode_runs_new['date']= date;
barcode_runs_new['fastq_R1']=directories;

# %%
#okay, so note that we should not overwrite the old barcode_runs file with just the new info. So we need to concatenate.

#save barcode_runs_current as an archive in case of a mistake
barcode_runs_current.to_csv('barcode_runs_current_240406_3.csv');


dfs= [barcode_runs_current, barcode_runs_new];

barcode_runs_final = pd.concat(dfs)

# %%
barcode_runs_final
# Out:
#     Unnamed: 0                            sample library      date  \
# 0          0.0   A-240129-rescue_1-no_antibody-1       A  20240129
# 1          1.0   A-240129-rescue_1-no_antibody-2       A  20240129
# 2          2.0          A-240129-rescue_1-VSVG-1       A  20240129
# 3          3.0   A-240222-rescue_2-no_antibody-1       A  20240222
# 4          4.0   A-240222-rescue_2-no_antibody-2       A  20240222
# 5          5.0   A-240222-rescue_2-no_antibody-3       A  20240222
# 6          6.0          A-240222-rescue_2-VSVG-1       A  20240222
# 7          7.0    A-240319-rescue_2-RVA122-150-1       A  20240319
# 8          8.0    A-240319-rescue_2-RVA122-300-1       A  20240319
# 9          9.0    A-240319-rescue_2-RVA122-600-1       A  20240319
# 10        10.0   A-240319-rescue_2-RVA122-1500-1       A  20240319
# 11        11.0   A-240319-rescue_2-RVA122-3000-1       A  20240319
# 12        12.0   A-240319-rescue_2-no_antibody-1       A  20240319
# 13        13.0   A-240319-rescue_2-no_antibody-2       A  20240319
# 14        14.0   A-240319-rescue_2-no_antibody-3       A  20240319
# 15        15.0     A-240319-rescue_2-RVC20-300-1       A  20240319
# 16        16.0     A-240319-rescue_2-RVC20-600-1       A  20240319
# 17        17.0    A-240319-rescue_2-RVC20-1200-1       A  20240319
# 18        18.0    A-240319-rescue_2-RVC20-3000-1       A  20240319
# 19        19.0    A-240319-rescue_2-RVC20-6000-1       A  20240319
# 20        20.0      A-240319-rescue_2-17C7-800-1       A  20240319
# 21        21.0     A-240319-rescue_2-17C7-2000-1       A  20240319
# 22        22.0     A-240319-rescue_2-17C7-4000-1       A  20240319
# 23        23.0    A-240319-rescue_2-17C7-10000-1       A  20240319
# 24        24.0    A-240319-rescue_2-17C7-25000-1       A  20240319
# 25         0.0   A-240331-rescue_4-no_antibody-1       A  20240331
# 26         1.0   A-240331-rescue_4-no_antibody-2       A  20240331
# 27         2.0   A-240331-rescue_4-no_antibody-3       A  20240331
# 28         3.0      A-240331-rescue_4-RVC58-50-1       A  20240331
# 29         4.0     A-240331-rescue_4-RVC58-250-1       A  20240331
# 30         5.0     A-240331-rescue_4-RVC58-500-1       A  20240331
# 31         6.0    A-240331-rescue_4-RVC58-1000-1       A  20240331
# 32         7.0    A-240331-rescue_4-RVC58-2500-1       A  20240331
# 33         8.0    A-240331-rescue_4-RVC58-5000-1       A  20240331
# 0          NaN    A-240331-rescue_4-CR4098-400-1       A  20240331
# 1          NaN   A-240331-rescue_4-CR4098-2000-1       A  20240331
# 2          NaN   A-240331-rescue_4-CR4098-4000-1       A  20240331
# 3          NaN   A-240331-rescue_4-CR4098-8000-1       A  20240331
# 4          NaN  A-240331-rescue_4-CR4098-20000-1       A  20240331
# 5          NaN  A-240331-rescue_4-CR4098-40000-1       A  20240331
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 4   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 5   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 6   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 7   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 8   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 9   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 10  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 11  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 12  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 13  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 14  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 15  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 16  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 17  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 18  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 19  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 20  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 21  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 22  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 23  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 24  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 25  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 26  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 27  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 28  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 29  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 30  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 31  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 32  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 33  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 0   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 4   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 5   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN

# %%
barcode_runs_final

#I'm going to trim some columns then re-save.

barcode_runs_final= barcode_runs_final.drop(columns= ['Unnamed: 0'], axis=1)

# %%
barcode_runs_final.to_csv('barcode_runs.csv')

# %%
barcode_runs_final
# Out:
#                               sample library      date  \
# 0    A-240129-rescue_1-no_antibody-1       A  20240129
# 1    A-240129-rescue_1-no_antibody-2       A  20240129
# 2           A-240129-rescue_1-VSVG-1       A  20240129
# 3    A-240222-rescue_2-no_antibody-1       A  20240222
# 4    A-240222-rescue_2-no_antibody-2       A  20240222
# 5    A-240222-rescue_2-no_antibody-3       A  20240222
# 6           A-240222-rescue_2-VSVG-1       A  20240222
# 7     A-240319-rescue_2-RVA122-150-1       A  20240319
# 8     A-240319-rescue_2-RVA122-300-1       A  20240319
# 9     A-240319-rescue_2-RVA122-600-1       A  20240319
# 10   A-240319-rescue_2-RVA122-1500-1       A  20240319
# 11   A-240319-rescue_2-RVA122-3000-1       A  20240319
# 12   A-240319-rescue_2-no_antibody-1       A  20240319
# 13   A-240319-rescue_2-no_antibody-2       A  20240319
# 14   A-240319-rescue_2-no_antibody-3       A  20240319
# 15     A-240319-rescue_2-RVC20-300-1       A  20240319
# 16     A-240319-rescue_2-RVC20-600-1       A  20240319
# 17    A-240319-rescue_2-RVC20-1200-1       A  20240319
# 18    A-240319-rescue_2-RVC20-3000-1       A  20240319
# 19    A-240319-rescue_2-RVC20-6000-1       A  20240319
# 20      A-240319-rescue_2-17C7-800-1       A  20240319
# 21     A-240319-rescue_2-17C7-2000-1       A  20240319
# 22     A-240319-rescue_2-17C7-4000-1       A  20240319
# 23    A-240319-rescue_2-17C7-10000-1       A  20240319
# 24    A-240319-rescue_2-17C7-25000-1       A  20240319
# 25   A-240331-rescue_4-no_antibody-1       A  20240331
# 26   A-240331-rescue_4-no_antibody-2       A  20240331
# 27   A-240331-rescue_4-no_antibody-3       A  20240331
# 28      A-240331-rescue_4-RVC58-50-1       A  20240331
# 29     A-240331-rescue_4-RVC58-250-1       A  20240331
# 30     A-240331-rescue_4-RVC58-500-1       A  20240331
# 31    A-240331-rescue_4-RVC58-1000-1       A  20240331
# 32    A-240331-rescue_4-RVC58-2500-1       A  20240331
# 33    A-240331-rescue_4-RVC58-5000-1       A  20240331
# 0     A-240331-rescue_4-CR4098-400-1       A  20240331
# 1    A-240331-rescue_4-CR4098-2000-1       A  20240331
# 2    A-240331-rescue_4-CR4098-4000-1       A  20240331
# 3    A-240331-rescue_4-CR4098-8000-1       A  20240331
# 4   A-240331-rescue_4-CR4098-20000-1       A  20240331
# 5   A-240331-rescue_4-CR4098-40000-1       A  20240331
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 4   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 5   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 6   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 7   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 8   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 9   /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 10  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 11  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 12  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 13  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 14  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 15  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 16  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 17  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 18  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 19  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 20  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 21  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 22  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 23  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 24  /shared/ngs/illumina/aaditham/240326_VH00319_4...    NaN
# 25  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 26  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 27  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 28  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 29  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 30  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 31  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 32  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 33  /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 0   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 4   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
# 5   /shared/ngs/illumina/aaditham/240405_VH01189_2...    NaN
