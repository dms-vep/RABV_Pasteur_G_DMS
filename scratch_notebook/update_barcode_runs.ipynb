# %%
import pandas as pd

# %%
#pull in current barcode runs so that I do not need to maintain ALL my prior selections. 

barcode_runs_current = pd.read_csv('barcode_runs.csv')

# %%
barcode_runs_current
# Out:
#     Unnamed: 0                           sample library      date  \
# 0            0  A-240129-rescue_1-no_antibody-1       A  20240129
# 1            1  A-240129-rescue_1-no_antibody-2       A  20240129
# 2            2         A-240129-rescue_1-VSVG-1       A  20240129
# 3            3  A-240222-rescue_2-no_antibody-1       A  20240222
# 4            4  A-240222-rescue_2-no_antibody-2       A  20240222
# 5            5  A-240222-rescue_2-no_antibody-3       A  20240222
# 6            6         A-240222-rescue_2-VSVG-1       A  20240222
# 7            0    A-240222-rescue_2-RVC20-290-1       A  20240222
# 8            1     A-240222-rescue_2-RVC20-58-1       A  20240222
# 9            2   A-240222-rescue_2-RVC20-11.6-1       A  20240222
# 10           3   A-240222-rescue_2-RVC20-2.32-1       A  20240222
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 4   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 5   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 6   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 7   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 8   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 9   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 10  /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN

# %%
#need to format sample names
lib = 'A';
date_selection = '240222'
rescue_num='2'; 

#notes rescue 1 was done on 13-Jan-2024; Rescue 2 was done 18-Jan-2024.

#either add string name of antibody (eg. 'RVA122'), say 'no_antibody', or 'VSVG' for VSV-G selections
#Then add '-#' where # is the replicate number. Eg replicate 1 is '-1' and so on.

conditions = ['RVA122-150-1','RVA122-30-1','RVA122-5-1','RVA122-1-1'];


#make sample names
sample_names = []

for i in conditions:
    sample = lib+'-'+date_selection+'-'+'rescue_'+rescue_num+'-'+i;
    print(sample)
    sample_names.append(sample)

print(sample_names)
# Out:
# A-240222-rescue_2-RVA122-150-1
# A-240222-rescue_2-RVA122-30-1
# A-240222-rescue_2-RVA122-5-1
# A-240222-rescue_2-RVA122-1-1
# ['A-240222-rescue_2-RVA122-150-1', 'A-240222-rescue_2-RVA122-30-1', 'A-240222-rescue_2-RVA122-5-1', 'A-240222-rescue_2-RVA122-1-1']

# %%
#copy-paste directories -- match order for names

directories=['/shared/ngs/illumina/aaditham/240304_VH00699_452_AAFJH2LM5/Unaligned/Project_aaditham/LibA_VSV-mCherry_RVA122_150_S5_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240304_VH00699_452_AAFJH2LM5/Unaligned/Project_aaditham/LibA_VSV-mCherry_RVA122_30_S6_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240304_VH00699_452_AAFJH2LM5/Unaligned/Project_aaditham/LibA_VSV-mCherry_RVA122_5_S7_R1_001.fastq.gz',
             '/shared/ngs/illumina/aaditham/240304_VH00699_452_AAFJH2LM5/Unaligned/Project_aaditham/LibA_VSV-mCherry_RVA122_1_S8_R1_001.fastq.gz'];

# %%
libraries = ['A','A','A','A'];
date = [20240222,20240222,20240222,20240222];

# %%
#update barcode_runs_new
barcode_runs_new = pd.DataFrame()

barcode_runs_new['sample']=sample_names;
barcode_runs_new['library']=libraries;
barcode_runs_new['date']= date;
barcode_runs_new['fastq_R1']=directories;

# %%
#okay, so note that we should not overwrite the old barcode_runs file with just the new info. So we need to concatenate.

#save barcode_runs_current as an archive in case of a mistake
barcode_runs_current.to_csv('barcode_runs_current_240305.csv');


dfs= [barcode_runs_current, barcode_runs_new];

barcode_runs_final = pd.concat(dfs)

# %%
barcode_runs_final
# Out:
#     Unnamed: 0                           sample library      date  \
# 0          0.0  A-240129-rescue_1-no_antibody-1       A  20240129
# 1          1.0  A-240129-rescue_1-no_antibody-2       A  20240129
# 2          2.0         A-240129-rescue_1-VSVG-1       A  20240129
# 3          3.0  A-240222-rescue_2-no_antibody-1       A  20240222
# 4          4.0  A-240222-rescue_2-no_antibody-2       A  20240222
# 5          5.0  A-240222-rescue_2-no_antibody-3       A  20240222
# 6          6.0         A-240222-rescue_2-VSVG-1       A  20240222
# 7          0.0    A-240222-rescue_2-RVC20-290-1       A  20240222
# 8          1.0     A-240222-rescue_2-RVC20-58-1       A  20240222
# 9          2.0   A-240222-rescue_2-RVC20-11.6-1       A  20240222
# 10         3.0   A-240222-rescue_2-RVC20-2.32-1       A  20240222
# 0          NaN   A-240222-rescue_2-RVA122-150-1       A  20240222
# 1          NaN    A-240222-rescue_2-RVA122-30-1       A  20240222
# 2          NaN     A-240222-rescue_2-RVA122-5-1       A  20240222
# 3          NaN     A-240222-rescue_2-RVA122-1-1       A  20240222
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 4   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 5   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 6   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 7   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 8   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 9   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 10  /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 0   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 1   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 2   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN

# %%
barcode_runs_final

#I'm going to trim some columns then re-save.

barcode_runs_final= barcode_runs_final.drop(['Unnamed: 0'], axis=1)

# %%
barcode_runs_final.to_csv('barcode_runs.csv')

# %%
barcode_runs_final
# Out:
#                              sample library      date  \
# 0   A-240129-rescue_1-no_antibody-1       A  20240129
# 1   A-240129-rescue_1-no_antibody-2       A  20240129
# 2          A-240129-rescue_1-VSVG-1       A  20240129
# 3   A-240222-rescue_2-no_antibody-1       A  20240222
# 4   A-240222-rescue_2-no_antibody-2       A  20240222
# 5   A-240222-rescue_2-no_antibody-3       A  20240222
# 6          A-240222-rescue_2-VSVG-1       A  20240222
# 7     A-240222-rescue_2-RVC20-290-1       A  20240222
# 8      A-240222-rescue_2-RVC20-58-1       A  20240222
# 9    A-240222-rescue_2-RVC20-11.6-1       A  20240222
# 10   A-240222-rescue_2-RVC20-2.32-1       A  20240222
# 0    A-240222-rescue_2-RVA122-150-1       A  20240222
# 1     A-240222-rescue_2-RVA122-30-1       A  20240222
# 2      A-240222-rescue_2-RVA122-5-1       A  20240222
# 3      A-240222-rescue_2-RVA122-1-1       A  20240222
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 1   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 2   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 4   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 5   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 6   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 7   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 8   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 9   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 10  /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 0   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 1   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 2   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
# 3   /shared/ngs/illumina/aaditham/240304_VH00699_4...    NaN
