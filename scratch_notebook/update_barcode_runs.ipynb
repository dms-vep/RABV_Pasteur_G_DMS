# %%
import pandas as pd

# %%
#pull in current barcode runs so that I do not need to maintain ALL my prior selections. 

barcode_runs_current = pd.read_csv('barcode_runs.csv')

# %%
barcode_runs_current
# Out:
#     Unnamed: 0                           sample library      date  \
# 0            0  A-240129-rescue_1-no_antibody-1       A  20240129
# 1            1  A-240129-rescue_1-no_antibody-2       A  20240129
# 2            2         A-240129-rescue_1-VSVG-1       A  20240129
# 3            3  A-240222-rescue_2-no_antibody-1       A  20240222
# 4            4  A-240222-rescue_2-no_antibody-2       A  20240222
# ..         ...                              ...     ...       ...
# 90          12   B-240510-rescue_2-CR57-10000-1       B  20240510
# 91          13   B-240510-rescue_2-CR57-20000-1       B  20240510
# 92          14  B-240510-rescue_2-no_antibody-1       B  20240510
# 93          15  B-240510-rescue_2-no_antibody-2       B  20240510
# 94          16  B-240510-rescue_2-no_antibody-3       B  20240510
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# ...

# %%
#need to format sample names
lib = 'B';
date_selection = '240507'
rescue_num='2'; 

#notes rescue 1 was done on 13-Jan-2024; Rescue 2 was done 18-Jan-2024. Rescue 3 was done 09-Mar-2024

#either add string name of antibody (eg. 'RVA122'), say 'no_antibody', or 'VSVG' for VSV-G selections
#Then add '-#' where # is the replicate number. Eg replicate 1 is '-1' and so on.

conditions = ['CR4098_400-1',
              'CR4098_2000-1',
              'CR4098_4000-1',
              'CR4098_8000-1',
              'CR4098-20000-1',
              'RVC20-600-1',
              'RVC20-1200-1',
              'RVC20-3000-1',
              'RVC20-6000-1',
              'RVC58-500-1',
              'RVC58-1000-1',
              'RVC58-2500-1',
              'RVC58-5000-1',
              'no_antibody-1',
              'no_antibody-2',
              'no_antibody-3',
              'no_antibody-4'];


#make sample names
sample_names = []

for i in conditions:
    sample = lib+'-'+date_selection+'-'+'rescue_'+rescue_num+'-'+i;
    print(sample)
    sample_names.append(sample)

print(sample_names)
# Out:
# B-240507-rescue_2-CR4098_400-1
# B-240507-rescue_2-CR4098_2000-1
# B-240507-rescue_2-CR4098_4000-1
# B-240507-rescue_2-CR4098_8000-1
# B-240507-rescue_2-CR4098-20000-1
# B-240507-rescue_2-RVC20-600-1
# B-240507-rescue_2-RVC20-1200-1
# B-240507-rescue_2-RVC20-3000-1
# B-240507-rescue_2-RVC20-6000-1
# B-240507-rescue_2-RVC58-500-1
# B-240507-rescue_2-RVC58-1000-1
# B-240507-rescue_2-RVC58-2500-1
# B-240507-rescue_2-RVC58-5000-1
# B-240507-rescue_2-no_antibody-1
# B-240507-rescue_2-no_antibody-2
# B-240507-rescue_2-no_antibody-3
# B-240507-rescue_2-no_antibody-4
# ...

# %%
#copy-paste directories -- match order for names

directories=['/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-CR4098_400_S23_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-CR4098_2000_S24_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-CR4098_4000_S25_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-CR4098_8000_S26_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-CR4098_20000_S27_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC20_600_S28_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC20_1200_S29_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC20_3000_S30_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC20_6000_S31_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC58_500_S18_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC58_1000_S19_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC58_2500_S21_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-RVC58_5000_S22_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-NoAntibody_1_S32_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-NoAntibody_2_S33_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-NoAntibody_3_S34_R1_001.fastq.gz',
'/shared/ngs/illumina/aaditham/240520_VH01189_285_AACK3LVHV/Unaligned/Project_aaditham/240507_LibB-NoAntibody_4_S35_R1_001.fastq.gz'];

# %%
library='B';
date_value = 20240507;

libraries = [];
date = [];

for i in range(0, len(directories)):
    libraries.append(library);
    date.append(date_value);

# %%
print(libraries)
print(date)
# Out:
# ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B']
# [20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507, 20240507]

# %%
#update barcode_runs_new
barcode_runs_new = pd.DataFrame()

barcode_runs_new['sample']=sample_names;
barcode_runs_new['library']=libraries;
barcode_runs_new['date']= date;
barcode_runs_new['fastq_R1']=directories;

# %%
#okay, so note that we should not overwrite the old barcode_runs file with just the new info. So we need to concatenate.

#save barcode_runs_current as an archive in case of a mistake
#barcode_runs_current.to_csv('barcode_runs_current_240408_CR57-added.csv');


dfs= [barcode_runs_current, barcode_runs_new];

barcode_runs_final = pd.concat(dfs)

# %%
barcode_runs_final
# Out:
#     Unnamed: 0                           sample library      date  \
# 0          0.0  A-240129-rescue_1-no_antibody-1       A  20240129
# 1          1.0  A-240129-rescue_1-no_antibody-2       A  20240129
# 2          2.0         A-240129-rescue_1-VSVG-1       A  20240129
# 3          3.0  A-240222-rescue_2-no_antibody-1       A  20240222
# 4          4.0  A-240222-rescue_2-no_antibody-2       A  20240222
# ..         ...                              ...     ...       ...
# 12         NaN   B-240507-rescue_2-RVC58-5000-1       B  20240507
# 13         NaN  B-240507-rescue_2-no_antibody-1       B  20240507
# 14         NaN  B-240507-rescue_2-no_antibody-2       B  20240507
# 15         NaN  B-240507-rescue_2-no_antibody-3       B  20240507
# 16         NaN  B-240507-rescue_2-no_antibody-4       B  20240507
#
#                                              fastq_R1  notes
# 0   /shared/ngs/illumina/aaditham/240206_VH01189_2...    NaN
# ...

# %%
barcode_runs_final

#I'm going to trim some columns then re-save.

barcode_runs_final= barcode_runs_final.drop(columns= ['Unnamed: 0'], axis=1)

# %%
barcode_runs_final.to_csv('barcode_runs.csv')

# %%
barcode_runs_final.head(20)
# Out:
#                              sample library      date  \
# 0   A-240129-rescue_1-no_antibody-1       A  20240129
# 1   A-240129-rescue_1-no_antibody-2       A  20240129
# 2          A-240129-rescue_1-VSVG-1       A  20240129
# 3   A-240222-rescue_2-no_antibody-1       A  20240222
# 4   A-240222-rescue_2-no_antibody-2       A  20240222
# 5   A-240222-rescue_2-no_antibody-3       A  20240222
# 6          A-240222-rescue_2-VSVG-1       A  20240222
# 7    A-240319-rescue_2-RVA122-150-1       A  20240319
# 8    A-240319-rescue_2-RVA122-300-1       A  20240319
# 9    A-240319-rescue_2-RVA122-600-1       A  20240319
# 10  A-240319-rescue_2-RVA122-1500-1       A  20240319
# 11  A-240319-rescue_2-RVA122-3000-1       A  20240319
# 12  A-240319-rescue_2-no_antibody-1       A  20240319
# 13  A-240319-rescue_2-no_antibody-2       A  20240319
# 14  A-240319-rescue_2-no_antibody-3       A  20240319
# 15    A-240319-rescue_2-RVC20-300-1       A  20240319
# ...
